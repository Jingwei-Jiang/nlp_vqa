# %%
import dataset

# %%
a = dataset.VQA_dataset(train=True)
# Out:
# {'no': 0, 'yes': 1, '1': 2, '2': 3, 'white': 4, '3': 5, '0': 6, 'black': 7, 'red': 8, 'blue': 9, '4': 10, 'brown': 11, 'green': 12, 'yellow': 13, '5': 14, 'gray': 15, 'nothing': 16, '6': 17, 'baseball': 18, 'frisbee': 19, 'pizza': 20, 'right': 21, 'kitchen': 22, 'none': 23, 'tennis': 24, 'left': 25, 'wood': 26, 'bathroom': 27, 'orange': 28, '7': 29, 'pink': 30, '8': 31, 'living room': 32, 'dog': 33, 'man': 34, 'cat': 35, 'phone': 36, 'silver': 37, 'skateboarding': 38, '10': 39, 'grass': 40, 'kite': 41, 'water': 42, 'cake': 43, 'table': 44, 'surfing': 45, 'skateboard': 46, 'tan': 47, 'skiing': 48, 'black and white': 49, 'snow': 50, 'wii': 51, 'standing': 52, 'surfboard': 53, '9': 54, 'cow': 55, 'laptop': 56, 'bus': 57, 'giraffe': 58, 'snowboarding': 59, 'woman': 60, 'purple': 61, 'elephant': 62, 'horse': 63, 'motorcycle': 64, 'stop': 65, 'soccer': 66, 'apple': 67, 'food': 68, 'banana': 69, 'sunny': 70, 'male': 71, 'beach': 72, '20': 73, 'eating': 74, 'clear': 75, 'unknown': 76, 'maybe
# ...

# %%
for item in a.answers:
    print(item)
    break
# Out:
# ['yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']

# %%
a.ans_vocab_len
# Out:
# 17625
